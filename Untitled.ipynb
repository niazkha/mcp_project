# %%
import os

ref_dir = "/home/researcher/mcp_project/03_reference"
files = os.listdir(ref_dir)

print(f"Contents of {ref_dir}:")
for f in files:
    print(f" - {f}")
# Out:
# Contents of /home/researcher/mcp_project/03_reference:
#  - GRCh38.primary_assembly.genome.fa.sa
#  - GRCh38.primary_assembly.genome.fa.ann
#  - GRCh38.primary_assembly.genome.fa
#  - GRCh38.primary_assembly.genome.fa.amb
#  - GRCh38.primary_assembly.genome.fa.pac
#  - GRCh38.primary_assembly.genome.fa.bwt
